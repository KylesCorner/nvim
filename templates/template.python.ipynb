# %% [markdown]
# # 📘 Notebook Title
# A short description of this notebook's purpose.

# %%
# 🔧 Setup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 📂 Load Data
# df = pd.read_csv('your-data.csv')
# df.head()

# %%
# 📊 Plot Example
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title('Sine Wave')
plt.show()
